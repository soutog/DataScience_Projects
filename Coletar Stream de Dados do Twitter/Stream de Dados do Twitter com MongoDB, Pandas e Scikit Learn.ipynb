# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.7.6

# %% [markdown]
# ## Stream de Dados do Twitter com MongoDB, Pandas e Scikit Learn

# %% [markdown]
# ## Preparando a Conexão com o Twitter

# %%
# Instala o pacote tweepy
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /home/gabriel/anaconda3/lib/python3.7/site-packages (3.9.0)
# Requirement already satisfied: six>=1.10.0 in /home/gabriel/anaconda3/lib/python3.7/site-packages (from tweepy) (1.14.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/gabriel/anaconda3/lib/python3.7/site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /home/gabriel/anaconda3/lib/python3.7/site-packages (from tweepy) (2.22.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/gabriel/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/gabriel/anaconda3/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/gabriel/anaconda3/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/gabriel/anaconda3/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gabriel/anaconda3/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy) (2019.11.28)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /home/gabriel/anaconda3/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)

# %%
# Importando os módulos Tweepy, Datetime e Json
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from datetime import datetime
import json

# %% [markdown]
# Veja no manual em pdf como criar sua API no Twitter e configure as suas chaves abaixo.

# %%
# Adicione aqui sua Consumer Key
consumer_key = "xxxxxxxxxx"

# %%
# Adicione aqui sua Consumer Secret 
consumer_secret = "xxxxxxxxxxxxxxxxx"

# %%
# Adicione aqui seu Access Token
access_token = "xxxxxxxxxxxxx"

# %%
# Adicione aqui seu Access Token Secret
access_token_secret = "xxxxxxxxxxxxxxxxxxxx"

# %%
# Criando as chaves de autenticação
auth = OAuthHandler(consumer_key, consumer_secret)

# %%
auth.set_access_token(access_token, access_token_secret)

# %%
# Criando uma classe para capturar os stream de dados do Twitter e 
# armazenar no MongoDB
class MyListener(StreamListener):
    def on_data(self, dados):
        tweet = json.loads(dados)
        created_at = tweet["created_at"]
        id_str = tweet["id_str"]
        text = tweet["text"]
        obj = {"created_at":created_at,"id_str":id_str,"text":text,}
        tweetind = col.insert_one(obj).inserted_id
        print (obj)
        return True

# %%
# Criando o objeto mylistener
mylistener = MyListener()

# %%
# Criando o objeto mystream
mystream = Stream(auth, listener = mylistener)

# %% [markdown]
# ## Preparando a Conexão com o MongoDB

# %%
# Importando do PyMongo o módulo MongoClient
from pymongo import MongoClient

# %%
# Criando a conexão ao MongoDB (instalado e inicializado)
client = MongoClient('localhost', 27017)

# %%
# Criando o banco de dados twitterdb
db = client.twitterdb

# %%
# Criando a collection "col"
col = db.tweets

# %%
# Criando uma lista de palavras chave para buscar nos Tweets
keywords = ['Big Data', 'Python', 'Data Mining', 'Data Science']

# %% [markdown]
# ## Coletando os Tweets

# %%
# Iniciando o filtro e gravando os tweets no MongoDB
mystream.filter(track=keywords)
# Out:
# {'created_at': 'Mon Aug 17 21:24:16 +0000 2020', 'id_str': '1295471532295282688', 'text': 'NLP For WhatsApp Chats #ArtificialIntelligence #deeplearning #learning  https://t.co/uIV2kZ71Ma', '_id': ObjectId('5f3af58590e2b0637bd42ea0')}
# {'created_at': 'Mon Aug 17 21:24:19 +0000 2020', 'id_str': '1295471543011639298', 'text': 'RT @SiccoVanHoegee: @PhoenixNLer @kikkertje17 @ContainmentNu @arieslob Nederland staat ook in het rood tussen een groen Engeland en Duitsla…', '_id': ObjectId('5f3af58890e2b0637bd42ea1')}
# {'created_at': 'Mon Aug 17 21:24:23 +0000 2020', 'id_str': '1295471559482589184', 'text': 'RT @antgrasso: The Data Science Capabilities Venn Diagram identifies the key objectives and capabilities for the three key data science rol…', '_id': ObjectId('5f3af58c90e2b0637bd42ea2')}
# {'created_at': 'Mon Aug 17 21:24:25 +0000 2020', 'id_str': '1295471571381956611', 'text': '@darkcyk Le lapin dans Monty Python sacré Graal', '_id': ObjectId('5f3af58f90e2b0637bd42ea3')}
# {'created_at': 'Mon Aug 17 21:24:27 +0000 2020', 'id_str': '1295471577635618818', 'text': "RT @hannah_kerner: Any recommendations for materials to learn the basics of Earth observation, current sensors, etc? I'm looking for materi…", '_id': ObjectId('5f3af59090e2b0637bd42ea4')}
# {'created_at': 'Mon Aug 17 21:24:27 +0000 2020', 'id_str': '1295471578474373120', 'text': 'バカだからpythonとか得意気に言ってもたいしてプログラミング出来ないのバレバレなウンコシノ', '_id': ObjectId('5f3af59090e2b0637bd42ea5')}
# {'created_at': 'Mon Aug 17 21:24:27 +0000 2020', 'id_str': '1295471579200184332', 'text': '@Deefensraum @vr_levi @MermaidFN @EpicNewsroom iOS and Android both have access to the same amount of data. The big… https://t.co/D2jqijLuvm', '_id': ObjectId('5f3af59190e2b0637bd42ea6')}
# {'created_at': 'Mon Aug 17 21:24:28 +0000 2020', 'id_str': '1295471583302221824', 'text': '@MariamBishar I bet it gave Chinese AI companies a headache reconfiguring their algos https://t.co/tlPneok4VR', '_id': ObjectId('5f3af59290e2b0637bd42ea7')}
# {'created_at': 'Mon Aug 17 21:24:33 +0000 2020', 'id_str': '1295471604978184192', 'text': 'Trying to learn C# coming from python and JS and man, this is tough', '_id': ObjectId('5f3af59790e2b0637bd42ea8')}
# {'created_at': 'Mon Aug 17 21:24:37 +0000 2020', 'id_str': '1295471619566166017', 'text': '📹 Systems Imagination uses SQL Server 2019 Big Data Clusters to deliver cutting-edge medical insights https://t.co/0sllw8DywN', '_id': ObjectId('5f3af59a90e2b0637bd42ea9')}
# {'created_at': 'Mon Aug 17 21:24:38 +0000 2020', 'id_str': '1295471623844368385', 'text': 'Deliver results quickly while keeping operating costs low. Learn how Systems Imagination uses @Microsoft SQL Server… https://t.co/UQ0387txeI', '_id': ObjectId('5f3af59b90e2b0637bd42eaa')}
# {'created_at': 'Mon Aug 17 21:24:40 +0000 2020', 'id_str': '1295471633923178498', 'text': 'Haha just drove down the main drag in the big state college town where I live haha lots of newly arrived students a… https://t.co/PaGmP1hYmg', '_id': ObjectId('5f3af59e90e2b0637bd42eab')}
# {'created_at': 'Mon Aug 17 21:24:41 +0000 2020', 'id_str': '1295471638021120003', 'text': "RT @Stefani94460352: @SenatorBerger @MACSchools Fear reduces the immune system.  That's science.\n\nSARS-COV2 has never been isolated nor seq…", '_id': ObjectId('5f3af59f90e2b0637bd42eac')}
# {'created_at': 'Mon Aug 17 21:24:44 +0000 2020', 'id_str': '1295471649748209668', 'text': 'IG: WOWFAKTA WOWFAKTA  ·  \n\nIndonesia adalah tempat ditemukannya ular terpanjang di dunia yaitu, Python Reticulatus… https://t.co/JBsak5NhjN', '_id': ObjectId('5f3af5a190e2b0637bd42ead')}
# {'created_at': 'Mon Aug 17 21:24:48 +0000 2020', 'id_str': '1295471664017420290', 'text': "@doctor_oxford @SimonUbsdell Big chums with Cameron, Diana Mary Harding aka Typhoid call me Dido. Elissa's so quali… https://t.co/Dp0hfcD70C", '_id': ObjectId('5f3af5a590e2b0637bd42eae')}
# {'created_at': 'Mon Aug 17 21:24:51 +0000 2020', 'id_str': '1295471676730286080', 'text': 'RT @mr_mading: E-commerce tech we built. 3D API in #NodeJS + #Blender with #Python API. Pluggable into any front: mobile, web or VR #tech #…', '_id': ObjectId('5f3af5a890e2b0637bd42eaf')}
# {'created_at': 'Mon Aug 17 21:24:54 +0000 2020', 'id_str': '1295471692140216320', 'text': 'RT @nw_nicholas: The #ALevelsResults fiasco shows that it doesn’t matter how hard you work, you will be held back by stupid, ignorant AI &amp;…', '_id': ObjectId('5f3af5ac90e2b0637bd42eb0')}
# {'created_at': 'Mon Aug 17 21:24:57 +0000 2020', 'id_str': '1295471702936358913', 'text': 'Deliver results quickly while keeping operating costs low. Learn how Systems Imagination uses @Microsoft SQL Server… https://t.co/lxVwxzpoup', '_id': ObjectId('5f3af5ae90e2b0637bd42eb1')}
# {'created_at': 'Mon Aug 17 21:24:57 +0000 2020', 'id_str': '1295471705314533376', 'text': 'Deliver results quickly while keeping operating costs low. Learn how Systems Imagination uses @Microsoft SQL Server… https://t.co/XZYJR4Zuof', '_id': ObjectId('5f3af5af90e2b0637bd42eb2')}
# {'created_at': 'Mon Aug 17 21:24:58 +0000 2020', 'id_str': '1295471705842843648', 'text': '@CryptoPetunia @a_centrism Because I’m a science, statistics, and data person too 🤓- the further I run, the closer… https://t.co/XltsZE2vIZ', '_id': ObjectId('5f3af5af90e2b0637bd42eb3')}
# {'created_at': 'Mon Aug 17 21:24:59 +0000 2020', 'id_str': '1295471711526227976', 'text': 'RT @SamanyouGarg: #GPT3 generates your API\n\nI have been exploring the capabilities of GPT-3. Built a demo app on top of it that lets you ge…', '_id': ObjectId('5f3af5b090e2b0637bd42eb4')}
# {'created_at': 'Mon Aug 17 21:24:59 +0000 2020', 'id_str': '1295471711530422279', 'text': 'RT @davidallengreen: Imagine when people discover what else is subjected to flawed algorithms applied to big data\n\nThe only real difference…', '_id': ObjectId('5f3af5b090e2b0637bd42eb5')}
# {'created_at': 'Mon Aug 17 21:25:00 +0000 2020', 'id_str': '1295471715108024321', 'text': 'NodeJS - The Complete Web Developer Bootcamp 2020 -&gt; https://t.co/OR7ZCVFSLg\n\n#udemy #coupons #webdevelopment… https://t.co/p8qAZ0z9hD', '_id': ObjectId('5f3af5b190e2b0637bd42eb6')}
# {'created_at': 'Mon Aug 17 21:25:02 +0000 2020', 'id_str': '1295471725854044160', 'text': 'RT @crankycripchro1: @cmccaff100692 @intrinsictweets @InfoMaguchm @DesegnistoR @Israel03178231 @Val_I_VanOrden @LakeishaInspir1 @Wrix2 @sev…', '_id': ObjectId('5f3af5b490e2b0637bd42eb7')}
# {'created_at': 'Mon Aug 17 21:25:02 +0000 2020', 'id_str': '1295471725971374081', 'text': 'RT @FreeDiscount45: NodeJS - The Complete Web Developer Bootcamp 2020 -&gt; https://t.co/OR7ZCVFSLg\n\n#udemy #coupons #webdevelopment #javascri…', '_id': ObjectId('5f3af5b490e2b0637bd42eb8')}
# {'created_at': 'Mon Aug 17 21:25:03 +0000 2020', 'id_str': '1295471729347710977', 'text': '一昨年の俺はPythonでHILSをやろうとしていたのかな😇', '_id': ObjectId('5f3af5b490e2b0637bd42eb9')}
# {'created_at': 'Mon Aug 17 21:25:08 +0000 2020', 'id_str': '1295471749979615236', 'text': 'RT @kikollan: La incidencia todavía es distinta por países, pero los casos crecen al ritmo similar en muchos países europeos:', '_id': ObjectId('5f3af5b990e2b0637bd42eba')}
# {'created_at': 'Mon Aug 17 21:25:10 +0000 2020', 'id_str': '1295471759043551232', 'text': '@muzozer2 Monty python demezsin yaaa', '_id': ObjectId('5f3af5bb90e2b0637bd42ebb')}
# {'created_at': 'Mon Aug 17 21:25:12 +0000 2020', 'id_str': '1295471765121110018', 'text': 'Deliver results quickly while keeping operating costs low. Learn how Systems Imagination uses @Microsoft SQL Server… https://t.co/1T6wOl8JZo', '_id': ObjectId('5f3af5bd90e2b0637bd42ebc')}
# {'created_at': 'Mon Aug 17 21:25:12 +0000 2020', 'id_str': '1295471766983323648', 'text': 'Convert MATLAB code into python - https://t.co/DuEwFpqB4f', '_id': ObjectId('5f3af5bd90e2b0637bd42ebd')}
# {'created_at': 'Mon Aug 17 21:25:14 +0000 2020', 'id_str': '1295471776714170373', 'text': 'RT @thefarmerjones: Haha just drove down the main drag in the big state college town where I live haha lots of newly arrived students and p…', '_id': ObjectId('5f3af5c090e2b0637bd42ebe')}
# {'created_at': 'Mon Aug 17 21:25:15 +0000 2020', 'id_str': '1295471780606275584', 'text': '#Python Tips!：自分に四則演算\n\nx = x + 1 は\n\nx += 1\n\nx = x /10 は\n\nx /= 10 って書くことができる！\n\n四則演算はもちろんOKだし、累乗 **、余りの計算 % でも同じことができ… https://t.co/ZfnJIOsug7', '_id': ObjectId('5f3af5c190e2b0637bd42ebf')}
# {'created_at': 'Mon Aug 17 21:25:16 +0000 2020', 'id_str': '1295471784351981571', 'text': 'Best advice EVER!', '_id': ObjectId('5f3af5c190e2b0637bd42ec0')}
# {'created_at': 'Mon Aug 17 21:25:17 +0000 2020', 'id_str': '1295471787925557249', 'text': 'RT @davidallengreen: Imagine when people discover what else is subjected to flawed algorithms applied to big data\n\nThe only real difference…', '_id': ObjectId('5f3af5c290e2b0637bd42ec1')}
# {'created_at': 'Mon Aug 17 21:25:18 +0000 2020', 'id_str': '1295471793080344577', 'text': 'Deliver results quickly while keeping operating costs low. Learn how Systems Imagination uses @Microsoft SQL Server… https://t.co/hRwz89neba', '_id': ObjectId('5f3af5c490e2b0637bd42ec2')}
# {'created_at': 'Mon Aug 17 21:25:21 +0000 2020', 'id_str': '1295471806359494658', 'text': 'Deliver results quickly while keeping operating costs low. Learn how Systems Imagination uses @Microsoft SQL Server… https://t.co/Y3ou7EpOvj', '_id': ObjectId('5f3af5c790e2b0637bd42ec3')}
# {'created_at': 'Mon Aug 17 21:25:23 +0000 2020', 'id_str': '1295471814676746247', 'text': 'hell yeah', '_id': ObjectId('5f3af5c990e2b0637bd42ec4')}
# {'created_at': 'Mon Aug 17 21:25:26 +0000 2020', 'id_str': '1295471826152366081', 'text': 'RT @mr_mading: E-commerce tech we built. 3D API in #NodeJS + #Blender with #Python API. Pluggable into any front: mobile, web or VR #tech #…', '_id': ObjectId('5f3af5cb90e2b0637bd42ec5')}
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1645         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1646             raise WantReadError()
#    1647         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-6a9070444200> in <module>
#       1 # Iniciando o filtro e gravando os tweets no MongoDB
# ----> 2 mystream.filter(track=keywords)
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     505             else:
#     506                 cache_content = False
# --> 507                 data = self._fp.read(amt) if not fp_closed else b""
#     508                 if (
#     509                     amt != 0 and not data
#
# ~/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     455             # Amount is given, implement using readinto
#     456             b = bytearray(amt)
# --> 457             n = self.readinto(b)
#     458             return memoryview(b)[:n].tobytes()
#     459         else:
#
# ~/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     489
#     490         if self.chunked:
# --> 491             return self._readinto_chunked(b)
#     492
#     493         if self.length is not None:
#
# ~/anaconda3/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     584         try:
#     585             while True:
# --> 586                 chunk_left = self._get_chunk_left()
#     587                 if chunk_left is None:
#     588                     return total_bytes
#
# ~/anaconda3/lib/python3.7/http/client.py in _get_chunk_left(self)
#     552                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#     556                 raise IncompleteRead(b'')
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     512     def _read_next_chunk_size(self):
#     513         # Read the next chunk size from the file
# --> 514         line = self.fp.readline(_MAXLINE + 1)
#     515         if len(line) > _MAXLINE:
#     516             raise LineTooLong("chunk size")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     323                 raise
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#     327             else:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     105         return poll_obj.poll(t)
#     106
# --> 107     return bool(_retry_on_intr(do_poll, timeout))
#     108
#     109
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     103         if t is not None:
#     104             t *= 1000
# --> 105         return poll_obj.poll(t)
#     106
#     107     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %% [markdown]
# ## --> Pressione o botão Stop na barra de ferramentas para encerrar a captura dos Tweets

# %% [markdown]
# ## Consultando os Dados no MongoDB

# %%
mystream.disconnect()

# %%
# Verificando um documento no collection
col.find_one()
# Out:
# {'_id': ObjectId('5f3af4e52869fcc8079fe1f9'),
#  'created_at': 'Mon Aug 17 21:21:36 +0000 2020',
#  'id_str': '1295470859352588288',
#  'text': "RT @RepAndyBiggsAZ: It's incumbent on officials from all around the state to listen to their constituents + the science and data and give A…"}

# %% [markdown]
# ## Análise de Dados com Pandas e Scikit-Learn

# %%
# criando um dataset com dados retornados do MongoDB
dataset = [{"created_at": item["created_at"], "text": item["text"],} for item in col.find()]

# %%
# Importando o módulo Pandas para trabalhar com datasets em Python
import pandas as pd
pd.__version__
# Out:
# '1.0.1'

# %%
# Criando um dataframe a partir do dataset 
df = pd.DataFrame(dataset)

# %%
# Imprimindo o dataframe
df
# Out:
#                         created_at  \
# 0   Mon Aug 17 21:21:36 +0000 2020
# 1   Mon Aug 17 21:21:36 +0000 2020
# 2   Mon Aug 17 21:21:36 +0000 2020
# 3   Mon Aug 17 21:21:38 +0000 2020
# 4   Mon Aug 17 21:21:39 +0000 2020
# 5   Mon Aug 17 21:21:39 +0000 2020
# 6   Mon Aug 17 21:21:43 +0000 2020
# 7   Mon Aug 17 21:21:45 +0000 2020
# 8   Mon Aug 17 21:21:46 +0000 2020
# 9   Mon Aug 17 21:24:16 +0000 2020
# 10  Mon Aug 17 21:24:19 +0000 2020
# 11  Mon Aug 17 21:24:23 +0000 2020
# 12  Mon Aug 17 21:24:25 +0000 2020
# 13  Mon Aug 17 21:24:27 +0000 2020
# 14  Mon Aug 17 21:24:27 +0000 2020
# 15  Mon Aug 17 21:24:27 +0000 2020
# 16  Mon Aug 17 21:24:28 +0000 2020
# 17  Mon Aug 17 21:24:33 +0000 2020
# 18  Mon Aug 17 21:24:37 +0000 2020
# 19  Mon Aug 17 21:24:38 +0000 2020
# 20  Mon Aug 17 21:24:40 +0000 2020
# 21  Mon Aug 17 21:24:41 +0000 2020
# 22  Mon Aug 17 21:24:44 +0000 2020
# 23  Mon Aug 17 21:24:48 +0000 2020
# 24  Mon Aug 17 21:24:51 +0000 2020
# 25  Mon Aug 17 21:24:54 +0000 2020
# 26  Mon Aug 17 21:24:57 +0000 2020
# 27  Mon Aug 17 21:24:57 +0000 2020
# 28  Mon Aug 17 21:24:58 +0000 2020
# 29  Mon Aug 17 21:24:59 +0000 2020
# 30  Mon Aug 17 21:24:59 +0000 2020
# 31  Mon Aug 17 21:25:00 +0000 2020
# 32  Mon Aug 17 21:25:02 +0000 2020
# 33  Mon Aug 17 21:25:02 +0000 2020
# 34  Mon Aug 17 21:25:03 +0000 2020
# 35  Mon Aug 17 21:25:08 +0000 2020
# 36  Mon Aug 17 21:25:10 +0000 2020
# 37  Mon Aug 17 21:25:12 +0000 2020
# 38  Mon Aug 17 21:25:12 +0000 2020
# 39  Mon Aug 17 21:25:14 +0000 2020
# 40  Mon Aug 17 21:25:15 +0000 2020
# 41  Mon Aug 17 21:25:16 +0000 2020
# 42  Mon Aug 17 21:25:17 +0000 2020
# 43  Mon Aug 17 21:25:18 +0000 2020
# 44  Mon Aug 17 21:25:21 +0000 2020
# 45  Mon Aug 17 21:25:23 +0000 2020
# 46  Mon Aug 17 21:25:26 +0000 2020
#
#                                                  text
# 0   RT @RepAndyBiggsAZ: It's incumbent on official...
# 1   @TMannu6 @Ope_sneakpastya Big baby. That's not...
# 2   RT @codingAna: Today @azolin_mafe taught me to...
# 3   ACE that class with our Scholars\n#Statistics\...
# 4   Fantastic! 🙂 Orange Dream Yellow Belly Red Str...
# 5   RT @BIScorecard: Great answer @tdav @BernardMa...
# 6   Introduction to the Tidyverse: Get started on ...
# 7   @GovInslee You have no idea how many people ap...
# 8   RT @MikeTamir: A comprehensive guide to downlo...
# 9   NLP For WhatsApp Chats #ArtificialIntelligence...
# 10  RT @SiccoVanHoegee: @PhoenixNLer @kikkertje17 ...
# 11  RT @antgrasso: The Data Science Capabilities V...
# 12    @darkcyk Le lapin dans Monty Python sacré Graal
# 13  RT @hannah_kerner: Any recommendations for mat...
# 14    バカだからpythonとか得意気に言ってもたいしてプログラミング出来ないのバレバレなウンコシノ
# 15  @Deefensraum @vr_levi @MermaidFN @EpicNewsroom...
# 16  @MariamBishar I bet it gave Chinese AI compani...
# 17  Trying to learn C# coming from python and JS a...
# 18  📹 Systems Imagination uses SQL Server 2019 Big...
# 19  Deliver results quickly while keeping operatin...
# 20  Haha just drove down the main drag in the big ...
# 21  RT @Stefani94460352: @SenatorBerger @MACSchool...
# 22  IG: WOWFAKTA WOWFAKTA  ·  \n\nIndonesia adalah...
# 23  @doctor_oxford @SimonUbsdell Big chums with Ca...
# 24  RT @mr_mading: E-commerce tech we built. 3D AP...
# 25  RT @nw_nicholas: The #ALevelsResults fiasco sh...
# 26  Deliver results quickly while keeping operatin...
# 27  Deliver results quickly while keeping operatin...
# 28  @CryptoPetunia @a_centrism Because I’m a scien...
# 29  RT @SamanyouGarg: #GPT3 generates your API\n\n...
# 30  RT @davidallengreen: Imagine when people disco...
# 31  NodeJS - The Complete Web Developer Bootcamp 2...
# 32  RT @crankycripchro1: @cmccaff100692 @intrinsic...
# 33  RT @FreeDiscount45: NodeJS - The Complete Web ...
# 34                     一昨年の俺はPythonでHILSをやろうとしていたのかな😇
# 35  RT @kikollan: La incidencia todavía es distint...
# 36               @muzozer2 Monty python demezsin yaaa
# 37  Deliver results quickly while keeping operatin...
# 38  Convert MATLAB code into python - https://t.co...
# 39  RT @thefarmerjones: Haha just drove down the m...
# 40  #Python Tips!：自分に四則演算\n\nx = x + 1 は\n\nx += 1...
# 41                                  Best advice EVER!
# 42  RT @davidallengreen: Imagine when people disco...
# 43  Deliver results quickly while keeping operatin...
# 44  Deliver results quickly while keeping operatin...
# 45                                          hell yeah
# 46  RT @mr_mading: E-commerce tech we built. 3D AP...

# %%
# Importando o módulo Scikit Learn
from sklearn.feature_extraction.text import CountVectorizer # contar o numero de vezes que certa palavra aparece no BD

# %%
import sklearn
sklearn.__version__
# Out:
# '0.22.1'

# %%
# Usando o método CountVectorizer para criar uma matriz de documentos
cv = CountVectorizer()
count_matrix = cv.fit_transform(df.text)

# %%
# Contando o número de ocorrências das principais palavras em nosso dataset
word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#             word  count
# 0            the     25
# 1             co     24
# 2          https     24
# 3             rt     18
# 4             to     16
# 5         python     13
# 6           data     12
# 7            and     10
# 8            big      8
# 9          learn      8
# 10           how      8
# 11        server      7
# 12           sql      7
# 13   imagination      7
# 14          that      7
# 15       deliver      7
# 16       systems      7
# 17          uses      7
# 18            of      6
# 19         while      6
# 20          with      6
# 21       quickly      6
# 22     operating      6
# 23       results      6
# 24       science      6
# 25            in      6
# 26     microsoft      6
# 27           low      6
# 28         costs      6
# 29       keeping      6
# 30            it      5
# 31           api      5
# 32           you      5
# 33           for      5
# 34        nodejs      4
# 35          tech      4
# 36            on      4
# 37           web      4
# 38          haha      4
# 39          have      4
# 40            ai      3
# 41          your      3
# 42        people      3
# 43            is      3
# 44          into      3
# 45         state      3
# 46          just      3
# 47            by      3
# 48         built      3
# 49  capabilities      3
